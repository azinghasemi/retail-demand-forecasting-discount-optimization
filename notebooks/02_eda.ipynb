# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook performs exploratory data analysis on the cleaned retail sales data.
#
# ## Analysis includes:
# 1. Sales trends over time
# 2. Seasonal patterns
# 3. Feature correlations
# 4. Distribution analysis
# 5. Outlier detection

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import load_data
from eda_plots import plot_sales_over_time, plot_seasonal_heatmap, plot_correlation_heatmap

# Load cleaned data
data_path = '../data/cleaned/grocery_cleaned.csv'
df = load_data(data_path)

print(f"Data shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
print(f"\nData types:\n{df.dtypes}")
print(f"\nSummary statistics:\n{df.describe()}")

# %%
# Plot sales over time
plot_sales_over_time(df, date_col='date', sales_col='sales', 
                     save_path='../reports/figures/sales_over_time.png')

# %%
# Plot seasonal heatmap
plot_seasonal_heatmap(df, date_col='date', sales_col='sales',
                     save_path='../reports/figures/seasonal_heatmap.png')

# %%
# Plot correlation heatmap
plot_correlation_heatmap(df, save_path='../reports/figures/heatmap_correlation.png')
